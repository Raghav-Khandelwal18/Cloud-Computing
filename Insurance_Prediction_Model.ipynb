# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %%
insurance = pd.read_csv("https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv ")

# %%
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance["age"]
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64

# %%
insurance["smoker"]
# Out:
# 0       yes
# 1        no
# 2        no
# 3        no
# 4        no
#        ...
# 1333     no
# 1334     no
# 1335     no
# 1336     no
# 1337    yes
# Name: smoker, Length: 1338, dtype: object

# %%
insurance["bmi"]
# Out:
# 0       27.900
# 1       33.770
# 2       33.000
# 3       22.705
# 4       28.880
#          ...
# 1333    30.970
# 1334    31.920
# 1335    36.850
# 1336    25.800
# 1337    29.070
# Name: bmi, Length: 1338, dtype: float64

# %%
insurance_one = pd.get_dummies(insurance)
insurance_one
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400        True     False      False
# 1      18  33.770         1   1725.55230       False      True       True
# 2      28  33.000         3   4449.46200       False      True       True
# 3      33  22.705         0  21984.47061       False      True       True
# 4      32  28.880         0   3866.85520       False      True       True
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830       False      True       True
# 1334   18  31.920         0   2205.98080        True     False       True
# 1335   18  36.850         0   1629.83350        True     False       True
# 1336   21  25.800         0   2007.94500        True     False       True
# 1337   61  29.070         0  29141.36030        True     False      False
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# ...

# %%
#Create x and y values (features and lables)
#Create the training and test sets
#build the neural networks

# %%
x = insurance_one.drop("charges",axis=1) #column drop axis = 0 then rows urs contains the
y = insurance_one["charges"] #dependent variable that predicts the data based on X

# %%
x.head()
# Out:
#    age     bmi  children  sex_female  sex_male  smoker_no  smoker_yes  \
# 0   19  27.900         0        True     False      False        True
# 1   18  33.770         1       False      True       True       False
# 2   28  33.000         3       False      True       True       False
# 3   33  22.705         0       False      True       True       False
# 4   32  28.880         0       False      True       True       False
#
#    region_northeast  region_northwest  region_southeast  region_southwest
# 0             False             False             False              True
# 1             False             False              True             False
# 2             False             False              True             False
# 3             False              True             False             False
# 4             False              True             False             False

# %%
y.head()
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %%
#Create the training and test sets

# %%
# this is the format of dataframe and will see this in the form of neurals network

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
len(x), len(x_train), len(x_test)
# Out:
# (1338, 1070, 268)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
len(y), len(y_train), len(y_test)
# Out:
# (1338, 1070, 268)

# %%
tf.random.set_seed(42)
insurance_module =tf.keras.Sequential([
    tf.keras.layers.Dense(12),
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(8),
    tf.keras.layers.Dense(6),
    tf.keras.layers.Dense(4),
    tf.keras.layers.Dense(2),
    tf.keras.layers.Dense(1)
])
insurance_module.compile(loss=tf.keras.losses.mae,
                         optimizer=tf.keras.optimizers.Adam(),
                         metrics=["mae"])
insurance_module.fit(x_train, y_train, epochs= 150 , verbose=1)
# Out:
# Epoch 1/150
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 13294.5957 - mae: 13294.5957
# Epoch 2/150
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13170.1270 - mae: 13170.1270
# Epoch 3/150
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12680.7959 - mae: 12680.7959
# Epoch 4/150
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10863.8848 - mae: 10863.8848
# Epoch 5/150
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7771.0684 - mae: 7771.0684
# Epoch 6/150
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7498.8394 - mae: 7498.8394
# Epoch 7/150
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7457.8057 - mae: 7457.8057
# Epoch 8/150
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7421.9482 - mae: 7421.9482
# Epoch 9/150
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7386.9248 - mae: 7386.9248
# Epoch 10/150
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7353.0283 - mae: 7353.0283
# Epoch 11/150
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7319.1104 - mae: 7319.1104
# ...

# %%
insurance_module.evaluate(x_test,y_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3247.9138 - mae: 3247.9138
# [3197.543701171875, 3197.543701171875]
